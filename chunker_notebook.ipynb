# %%
from scripts.chunker.chunker import chunk_collection
from collections import Counter

print("=" * 60)
print("Chunking Collection A")
print("=" * 60)

chunks = chunk_collection("A")

# ── Distribution stats ───────────────────────────────────────────
lengths = [len(c["text"]) for c in chunks]
print(f"\nTotal chunks : {len(chunks)}")
print(f"Avg length   : {sum(lengths) / len(lengths):.0f} chars")
print(f"Min length   : {min(lengths)} chars")
print(f"Max length   : {max(lengths)} chars")

# Chunks per source doc
per_doc = Counter(c["doc_id"] for c in chunks)
print(f"\n{'doc_id':<45} {'chunks':>6}")
print("-" * 53)
for doc_id, count in sorted(per_doc.items()):
    print(f"{doc_id:<45} {count:>6}")

# %%
# Change index to inspect any chunk
sample = chunks[0]

for key, val in sample.items():
    if key == "text":
        continue
    print(f"{key:<14}: {val}")

print(f"\n{'text':─<60}")
print(sample["text"])

# %%
# Change doc_id to explore any document's chunks
target_doc = "A_pittsburgh_britannica"

doc_chunks = [c for c in chunks if c["doc_id"] == target_doc]
print(f"{len(doc_chunks)} chunks for '{target_doc}':\n")

for c in doc_chunks:
    section_label = c["section"]
    sub_label     = f" › {c['subsection']}" if c["subsection"] else ""
    chars         = len(c["text"])
    print(f"  [{c['chunk_index']:>3}] {section_label}{sub_label}  ({chars} chars)")

# %%
from scripts.chunk_collection_b import chunk_collection_b

chunks_b = chunk_collection_b()

# %%
from collections import Counter
from pathlib import Path
import json

# Counts per doc
per_doc = Counter(c["doc_id"] for c in chunks_b)
print(f"{'doc_id':<40} {'chunks':>7}")
print("-" * 49)
for doc_id, count in sorted(per_doc.items()):
    print(f"{doc_id:<40} {count:>7}")

# Length stats
lengths = [len(c["text"]) for c in chunks_b]
print(f"\nTotal  : {len(chunks_b)}")
print(f"Avg    : {sum(lengths)/len(lengths):.0f} chars")
print(f"Min    : {min(lengths)}")
print(f"Max    : {max(lengths)}")

# %%
tax_chunks = [c for c in chunks_b if c["doc_id"] == "B_payroll_tax_regulations"]
sample = tax_chunks[0]
print(f"chunk_id : {sample['chunk_id']}")
print(f"section  : {sample['section']}")
print(f"subsection: {sample['subsection']}")
print()
print(sample["text"])

# %%
budget_chunks = [c for c in chunks_b if c["doc_id"] == "B_2025_operating_budget"]

print(f"Total budget chunks: {len(budget_chunks)}\n")

# Show a few examples
for c in budget_chunks[10:14]:
    print(f"── {c['chunk_id']} ──")
    print(c["text"])
    print()

# %% [markdown]
# ---
# ## Collection C: Chunking — Pittsburgh Events

# %%
from scripts.chunk_collection_c_pgh_events import chunk_collection_c

# Writes data/processed/C_chunks.jsonl
chunks_c = chunk_collection_c()
# Out:
# ============================================================
# Chunking Collection C — Pittsburgh Events
# ============================================================
#
# [pittsburgh.events]
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_march.md                              30 events  →  30 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_april.md                              30 events  →  30 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_may.md                                30 events  →  30 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_june.md                               30 events  →  30 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_july.md                               30 events  →  30 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_august.md                             30 events  →  30 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_september.md                          30 events  →  30 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_october.md                            15 events  →  15 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_november.md                            2 events  →  2 chunks
#   ⚠  Short card (1 fields): ['Pittsburgh, PA']
#   ✓  pgh_events_december.md                            1 events  →  1 chunks
#
# [downtownpittsburgh.com]
#   ✓  downtown_pgh_events_03.md                        49 events  →  49 chunks
#   ✓  downtown_pgh_events_04.md                         9 events  →  9 chunks
#   ✓  downtown_pgh_events_05.md                         8 events  →  8 chunks
#   ✓  downtown_pgh_events_06.md                         3 events  →  3 chunks
#   ✓  downtown_pgh_events_07.md                         2 events  →  2 chunks
#   ✓  downtown_pgh_events_08.md                         1 events  →  1 chunks
#   ✓  downtown_pgh_events_09.md                         1 events  →  1 chunks
#   ✓  downtown_pgh_events_10.md                         1 events  →  1 chunks
#   ✓  downtown_pgh_events_11.md                         1 events  →  1 chunks
#   ✓  downtown_pgh_events_12.md                         1 events  →  1 chunks
#
#   → Wrote 304 total chunks to data/processed/C_chunks.jsonl  (248.3 KB)
#      pittsburgh.events      : 228
#      downtownpittsburgh.com : 76

# %%
from scripts.process_recurring_events_csv_c import process_csv

# Update csv_path to wherever your CSV file is located
result = process_csv(
    csv_path="data/raw/recurring_events.csv",
    source_url="https://www.pittsburghmagazine.com/best-of-the-burgh-listings/",
)
print(result)
# Out:
#   ↓  Reading: recurring_events.csv
#   ✓  Loaded 370 records
#   ✓  Markdown → data/processed/recurring_events_pittsburgh.md  (145.9 KB)
#   ✓  Appended doc record to data/processed/C_docs.jsonl
# {'records': 370, 'md_path': 'data/processed/recurring_events_pittsburgh.md', 'jsonl_path': 'data/processed/C_docs.jsonl'}

# %%
from scripts.chunk_recurring_events_c import chunk_recurring_events

chunks_recurring = chunk_recurring_events(
    csv_path="data/raw/recurring_events.csv",
    source_url="https://www.pittsburghmagazine.com/best-of-the-burgh-listings/",
    append=True,   # merges with existing C_chunks.jsonl
)
# Out:
# ============================================================
# Chunking — Pittsburgh Recurring Events
# ============================================================
#   ✓  Loaded 370 records from recurring_events.csv
#
#   → Appended 370 chunks to data/processed/C_chunks.jsonl  (593.9 KB)
#      Free events : 79
#      Categories  :
#        Other Stuff                      60
#        Volunteers                       57
#        DJs                              35
#        Comedy                           20
#        Open Stage                       20
#        Literary                         17
#        Exhibits                         17
#        Jazz                             11
#        Outside                          11
#        Dance                            10
#        Other Music                      10
#        Community                        10
#        Visual Art                        9
#        Trivia                            9
#        Kidstuff                          7
#        Acoustic                          7
#        Fundraisers                       7
#        Games                             6
#        Submissions                       5
#        Theater                           4
#        Food & Drink Event                4
#        Exercise                          4
#        Opera                             3
#        Politics                          3
#        Sports                            3
#        World                             2
#        Classical                         2
#        Lecture                           2
#        Auditions                         2
#        Rock                              2
#        Special                           2
#        Blues                             2
#        Indie                             1
#        Screen                            1
#        Burlesque                         1
#        Meeting                           1
#        Festivals                         1
#        Holiday                           1
#        Electronic                        1

# %%
# Distribution by category
from collections import Counter

cats = Counter(c["category"] for c in chunks_recurring)
areas = Counter(c["area"] for c in chunks_recurring)

print(f"Total chunks: {len(chunks_recurring)}")
print(f"Free events : {sum(1 for c in chunks_recurring if c['is_free'])}\n")

print("By category:")
for cat, n in cats.most_common():
    print(f"  {cat or '(none)':<35} {n}")

print("\nBy area (top 10):")
for area, n in areas.most_common(10):
    print(f"  {area or '(none)':<35} {n}")
# Out:
# Total chunks: 370
# Free events : 79
#
# By category:
#   Other Stuff                         60
#   Volunteers                          57
#   DJs                                 35
#   Comedy                              20
#   Open Stage                          20
#   Literary                            17
#   Exhibits                            17
#   Jazz                                11
#   Outside                             11
#   Dance                               10
#   Other Music                         10
#   Community                           10
#   Visual Art                          9
#   Trivia                              9
#   Kidstuff                            7
#   Acoustic                            7
#   Fundraisers                         7
#   Games                               6
#   Submissions                         5
#   Theater                             4
#   Food & Drink Event                  4
#   Exercise                            4
#   Opera                               3
#   Politics                            3
#   Sports                              3
#   World                               2
#   Classical                           2
#   Lecture                             2
#   Auditions                           2
#   Rock                                2
#   Special                             2
#   Blues                               2
#   Indie                               1
#   Screen                              1
#   Burlesque                           1
#   Meeting                             1
#   Festivals                           1
#   Holiday                             1
#   Electronic                          1
#
# By area (top 10):
#   (none)                              77
#   Lawrenceville                       48
#   Downtown                            33
#   Oakland                             28
#   North Side                          24
#   Bloomfield                          13
#   Millvale                            10
#   Strip District                      9
#   Shadyside                           9
#   East Liberty                        8

# %%
# Free events in Oakland
results = [
    c for c in chunks_recurring
    if c["is_free"] and c["area"].lower() == "oakland"
]
print(f"Free events in Oakland: {len(results)}\n")
for c in results[:5]:
    print(c["text"])
    print()
# Out:
# Free events in Oakland: 5
#
# Event: BofA's Museums On Us® Offers Free Admission!
# Schedule: First Saturday, Sunday of every month
# Venue: Carnegie Museums of Pittsburgh
# Address: 4400 Forbes Ave, Pittsburgh, Oakland
# Price: Free
# Category: Visual Art
# Description: WHAT: Bank of America, Merrill and Bank of America Private Bank cardholders can receive FREE general admission to Carnegie Museums of Art and Natural History and The Andy Warhol Museum cultural attractions Saturday and Sunday.
# WHEN: Saturday, October 4th & Sunday, October 5th (+ the first full weekend of each month)
# WHERE: Learn something new this month with a visit to a participating cultural institution, including:
# -Carnegie Museums of Pittsburgh, 4400 Forbes Ave, Pittsburgh, PA 15213
# -The Andy Warhol Museum, 117 Sandusky St, Pittsburgh, PA 15212
#
# Event: Accessible Tech Training @ LBPH
# Schedule: Third Wednesday of every month, 1-2:30 p.m.
# Venue: Library for the Blind & Physically Handicapped
# Address: 4724 Baum Blvd, Pittsburgh, Oakland
# Price: FREE
# Category: Other Stuff
# Description: Need assistance with your smartphone or tablet? Join us for a hands-on tech training focusing on your devices accessibility options (voiceover/screen readers, magnification, enlarged fonts, etc). We can help with any operating system (iOS, Android), and any kind of device! Please bring your own device if you have one, if not, feel free to use one of ours!
#
# Event: Pittsburgh Self-inquiry Confrontation Meeting
# Schedule: Third Wednesday of every month, 7-9 p.m.
# Venue: Friends Meeting House
# Address: 4836 Ellsworth Ave., Pittsburgh, Oakland
# Price: free
# Category: Other Stuff
# Description: "Who am I?" is a distinct search for an answer to life's Big Questions. There are ways and means to pursue, authors to be found, teachers who advise, but sincere fellow seekers can be an invaluable source of inspiration and momentum on this path. All serious inquirers are welcome to take part in our Confrontation sessions which question our thinking and rationalizations to reveal obstacles to seeing clearly. Featured: writings of Ramana Maharshi, Nisargadatta, Richard Rose, Franklin Merrell-Wolff, Douglas Harding and others
#
# Event: Christian Science Church Service
# Schedule: Wednesdays, 7:30-8:30 p.m. and Sundays, 11-12 a.m.
# Venue: First Church of Christ, Scientist
# Address: 201 North Dithridge at Bayard Street, Oakland, Pittsburgh, Oakland
# Price: free
# Category: Community
# Description: An hour of quiet time for inspiration. Bible Lesson-Sermon and Hymns. Sunday School 11a for children. In church or email for Zoom invitation. Parking
#
# Event: Let's Speak English
# Schedule: Wednesdays, 5-6 p.m.
# Venue: Carnegie Library, Oakland
# Address: 4400 Forbes Avenue, Pittsburgh, Oakland
# Price: Free
# Category: Other Stuff
# Description: If English is not your native language, join our group for lively English conversation. Let’s Speak English meets in Classroom A every Wednesday (EXCEPT for July 4 and November 21).
# These classes are FREE.
# You do not have to register for the classes.
# You do not need to bring anything or buy anything.
# New participants are welcome at any time.
# This class is for adults, but young people are welcome as long as they behave respectfully.

# %%
from collections import Counter

per_month = Counter(c["section"] for c in chunks_c)
print(f"{'Month':<25} {'Chunks':>7}")
print("-" * 34)
for month, count in sorted(per_month.items()):
    print(f"{month:<25} {count:>7}")

print(f"\nTotal: {len(chunks_c)} event chunks")
# Out:
# Month                      Chunks
# ----------------------------------
# Apr 2026                       35
# Aug 2026                       30
# Dec 2026                        1
# Feb 2026                        7
# Jan 2026                       19
# Jul 2026                       30
# Jun 2026                       34
# Mar 2026                       64
# May 2026                       34
# Nov 2026                        4
# Oct 2026                       15
# Sep 2026                       31
#
# Total: 304 event chunks

# %%
for c in chunks_c[290:305]:
    print(f"── {c['chunk_id']} ──")
    print(c["text"])
    print(f"event_date: {c['event_date']}")
    print()
# Out:
# ── C_downtown_pgh_events_05__0004 ──
# Event Name: PSO in Libraries
# Date: Jan 13, 2026
# Description: Look for the Pittsburgh Symphony Orchestra in your community! These FREE chamber-style concerts feature PSO musicians performing curated programs at a local library near you. Click on "Get Tickets" to find performance dates in East Liberty, Downtown, Squirrel Hill, Beechview, and more. Arts + Culture, Sports + Recreation,
# Categories: Family, Outdoor, Tours
# event_date: 2026-01-13
#
# ── C_downtown_pgh_events_05__0005 ──
# Event Name: Beauty of the Burgh Bike Tour
# Date: Jan 1, 2026 at 10:00 am
# Description: Whether you are visiting Pittsburgh or you are a local, you will learn interesting facts about the history and culture of Pittsburgh while riding past beautiful sights and architecture. Arts + Culture,
# Categories: Tours
# event_date: 2026-01-01 10:00
#
# ── C_downtown_pgh_events_05__0006 ──
# Event Name: Visit the Old Allegheny Jail and Museum
# Date: Jan 5, 2026 at 11:30 am
# Description: Explore the Old Allegheny County Jail Museum, a preserved section of the historic 1886 jail located in Downtown Pittsburgh, open for free self-guided visits on the first and third Mondays of each month from 11:30 a.m. to 1:00 p.m. Sports + Recreation,
# Categories: Outdoor, Tours
# event_date: 2026-01-05 11:30
#
# ── C_downtown_pgh_events_05__0007 ──
# Event Name: Bikes & Brews Tour
# Date: Jun 28, 2025 at 2:00 pm
# Description: Bike the Burgh tour tour packed with lots of history, facts about beer making, and beer samples from each of the places we stop at
# event_date: 2025-06-28 14:00
#
# ── C_downtown_pgh_events_06__0000 ──
# Event Name: PSO in Libraries
# Date: Jan 13, 2026
# Description: Look for the Pittsburgh Symphony Orchestra in your community! These FREE chamber-style concerts feature PSO musicians performing curated programs at a local library near you. Click on "Get Tickets" to find performance dates in East Liberty, Downtown, Squirrel Hill, Beechview, and more.
# Categories: Entertainment, Music
# event_date: 2026-01-13
#
# ── C_downtown_pgh_events_06__0001 ──
# Event Name: Morgan Wallen Live In Pittsburgh - Still The Problem Tour
# Date: Jun 5, 2026 at 5:00 pm
# Description: Morgan Wallen brings the Still The Problem Tour to Acrisure Stadium in Pittsburgh for two unforgettable nights! Arts + Culture, Sports + Recreation,
# Categories: Family, Outdoor, Tours
# event_date: 2026-06-05 17:00
#
# ── C_downtown_pgh_events_06__0002 ──
# Event Name: Beauty of the Burgh Bike Tour
# Date: Jan 1, 2026 at 10:00 am
# Description: Whether you are visiting Pittsburgh or you are a local, you will learn interesting facts about the history and culture of Pittsburgh while riding past beautiful sights and architecture. []( []( []( []( []( **Contact Us** 412-566-4190 **Pittsburgh Downtown Partnership** 307 Fourth Avenue – Floor 2 Pittsburgh, PA 15222 - Facebook - Twitter - LinkedIn - Email - Things to do - Programs + Activities - Downtown Events Calendar - Downtown Business Directory - Visit - Accommodations - Getting Around - Parking - Public Restrooms - Construction Updates - Events - Live - Housing + Residential Directory - Downtown Lifestyle - Residential Resources - Services - Get Involved - Membership - Employment Opportunities - Volunteer in Downtown - Vendor, Performer & Sponsor Opportunities - Downtown Placemaking Grant - Development Activities Meetings - Do Business - Downtown Activity Dashboard - Downtown Rent Abatement Program - Property Opportunities - Retail + Small Business Resources - Co-Working + Shared Office - Developer Resources - Project Pop-Up - Paris to Pittsburgh - Development Activity - About - Our Staff - Board of Directors - Business Improvement District - On-Street Services - Economic Development - Mobility + Transportation - Annual Meetings - Research + Reports - Programs + Activities - Publications + Social Media Connect With Us... © 2026 Pittsburgh Downtown Partnership. All Rights Reserved. \| Terms Of Use \| Privacy Policy 201620172018201920202021202220232024202520262027202820292030203120322033203420352036 |     |     |     | | --- | --- | --- | | Jan | Feb | Mar | | Apr | May | Jun | | Jul | Aug | Sep | | Oct | Nov | Dec |
# Categories: Email Us, The Bank Tower, Share this page
Services - Economic Development - Mobility + Transportation - Annual Meetings - Research + Reports - Programs + Activities - Publications + Social Media Connect With Us... © 2026 Pittsburgh Downtown Partnership. All Rights Reserved. \| Terms Of Use \| Privacy Policy 201620172018201920202021202220232024202520262027202820292030203120322033203420352036 |     |     |     | | --- | --- | --- | | Jan | Feb | Mar | | Apr | May | Jun | | Jul | Aug | Sep | | Oct | Nov | Dec |
# Categories: Email Us, The Bank Tower, Share this page
# event_date: 2026-01-01 10:00

# %%
# Filter events in May 2026 without using embeddings
may_events = [
    c for c in chunks_c
    if c.get("event_date", "").startswith("2026-05")
]
print(f"Events in May 2026: {len(may_events)}\n")
for c in may_events[:]:
    print(f"  {c['event_date']}  {c['text'].splitlines()[0]}")
# Out:
# Events in May 2026: 34
#
#   2026-05-01 18:40  Event Name: Pittsburgh Pirates vs. Cincinnati Reds VIP Experience Available
#   2026-05-01 19:00  Event Name: Pittsburgh Symphony Orchestra: Star Wars The Empire Strikes Back In Concert
#   2026-05-01 19:00  Event Name: DeRay Davis
#   2026-05-01 19:30  Event Name: Howie Day
#   2026-05-01 19:30  Event Name: Demon Hunter
#   2026-05-01 20:00  Event Name: Lily Rose
#   2026-05-01 20:00  Event Name: Journey Thru the Ages
#   2026-05-01 20:00  Event Name: Heather McMahan
#   2026-05-01 20:00  Event Name: Beginnings - A Tribute To Chicago
#   2026-05-01 21:30  Event Name: DeRay Davis
#   2026-05-02 12:00  Event Name: Story Pirates
#   2026-05-02 16:05  Event Name: Pittsburgh Pirates vs. Cincinnati Reds VIP Experience Available
#   2026-05-02 18:30  Event Name: DeRay Davis
#   2026-05-02 19:00  Event Name: Felipe Esparza
#   2026-05-02 19:00  Event Name: Pittsburgh Riverhounds SC vs. Phoenix Rising FC
#   2026-05-02 19:00  Event Name: Pittsburgh Symphony Orchestra: Star Wars The Empire Strikes Back In Concert
#   2026-05-02 19:30  Event Name: Dear Evan Hansen
#   2026-05-02 20:00  Event Name: Nonpoint
#   2026-05-02 20:00  Event Name: Colin James, Matt Anderson & Terra Lightfoot
#   2026-05-02 20:00  Event Name: Bahamas
#   2026-05-02 20:00  Event Name: Afghan Whigs
#   2026-05-02 20:30  Event Name: Grunge Fest
#   2026-05-02 21:00  Event Name: DeRay Davis
#   2026-05-03 13:35  Event Name: Pittsburgh Pirates vs. Cincinnati Reds VIP Experience Available
#   2026-05-03 14:30  Event Name: Pittsburgh Symphony Orchestra: Star Wars The Empire Strikes Back In Concert
#   2026-05-03 15:00  Event Name: Central Pop
#   2026-05-03 18:00  Event Name: DeRay Davis
#   2026-05-03 18:30  Event Name: Wolves At the Gate
#   2026-05-03 19:30  Event Name: Alan Doyle
#   2026-05-05 17:30  Event Name: Behemoth
#   2026-05-22 12:00  Event Name: Just Another Bookish Ball
#   2026-05-16 09:00  Event Name: 2026 Walk To Cure Arthritis - Pittsburgh
#   2026-05-03 15:00  Event Name: Falstaff
#   2026-05-01 19:00  Event Name: Falstaff

# %%
venue_keyword = "Heinz"
venue_events = [
    c for c in chunks_c
    if venue_keyword.lower() in c.get("venue", "").lower()
]
print(f"Events at venues containing '{venue_keyword}': {len(venue_events)}\n")
for c in venue_events[:5]:
    print(c["text"])
    print()
# Out:
# Events at venues containing 'Heinz': 8
#
# Event Name: Pittsburgh Symphony Orchestra: American Soundscapes
# Date: Sun, Mar 01, 2026 at 2:30 PM
# Venue: Heinz Hall \| Capacity: 2676
# Location: 15222, 600 Penn Ave, Pittsburgh, PA, US
#
# Event Name: Pittsburgh Symphony Orchestra: Star Wars The Empire Strikes Back In Concert
# Date: Fri, May 01, 2026 at 7:00 PM
# Venue: Heinz Hall \| Capacity: 2676
# Location: 15222, 600 Penn Ave, Pittsburgh, PA, US
#
# Event Name: Pittsburgh Symphony Orchestra: Star Wars The Empire Strikes Back In Concert
# Date: Sat, May 02, 2026 at 7:00 PM
# Venue: Heinz Hall \| Capacity: 2676
# Location: 15222, 600 Penn Ave, Pittsburgh, PA, US
#
# Event Name: Pittsburgh Symphony Orchestra: Star Wars The Empire Strikes Back In Concert
# Date: Sun, May 03, 2026 at 2:30 PM
# Venue: Heinz Hall \| Capacity: 2676
# Location: 15222, 600 Penn Ave, Pittsburgh, PA, US
#
# Event Name: Pittsburgh Symphony Orchestra: Byron Stripling - Disco Divas
# Date: Fri, Jun 05, 2026 at 7:30 PM
# Venue: Heinz Hall \| Capacity: 2676
# Location: 15222, 600 Penn Ave, Pittsburgh, PA, US

# %%
import sys
from pathlib import Path

REPO_ROOT  = Path(".")
SCRIPT_DIR = REPO_ROOT

sys.path.insert(0, str(SCRIPT_DIR))

from scripts.chunk_collection_c_cmu_events import (
    run,
    PROCESSED_DIR,
    DEFAULT_CAMPUS_MONTHS,
)

campus_months = DEFAULT_CAMPUS_MONTHS

docs, chunks = run(campus_months=campus_months, append=True)

import json
from collections import Counter
# Out:
# ============================================================
# Collection C — CMU Events Chunking
# ============================================================
#
# [events.cmu.edu — campus calendar]
#   ok  cmu_campus_events_20260301.md                     0 events  ->  0 chunks
#   ok  cmu_campus_events_20260401.md                    62 events  ->  62 chunks
#   ok  cmu_campus_events_20260501.md                    27 events  ->  27 chunks
#   ok  cmu_campus_events_20260601.md                    21 events  ->  21 chunks
#   ok  cmu_campus_events_20260701.md                    11 events  ->  11 chunks
#   ok  cmu_campus_events_20260801.md                     9 events  ->  9 chunks
#   ok  cmu_campus_events_20260901.md                     3 events  ->  3 chunks
#   ok  cmu_campus_events_20261001.md                     4 events  ->  4 chunks
#   ok  cmu_campus_events_20261101.md                     2 events  ->  2 chunks
#   ok  cmu_campus_events_20261201.md                     0 events  ->  0 chunks
#
# [cmu.edu/engage/events]
#   ok  cmu_engage_events.md                              5 sections  ->  5 chunks
#
#   -> append done
#      C_docs.jsonl   : 11 docs  (401.4 KB)
#      C_chunks.jsonl : 144 chunks  (742.5 KB)
#        events.cmu.edu campus : 139
#        cmu.edu engage        : 5

# %%
# ============================================================
# Notebook Cell — Chunk Collection D
# ============================================================
# 前置条件：
#   - clean_collection_d.py 已跑完，data/processed/D/ 下有清洗文件
#   - chunk_collection_d.py 位于 scripts/ 目录下
# ============================================================

import sys, json
from pathlib import Path
from collections import Counter

sys.path.insert(0, "scripts/")
from scripts.chunkers.chunk_collection_d import chunk_all, PROCESSED_D_DIR, OUT_DOCS, OUT_CHUNKS

# ── 参数 ─────────────────────────────────────────────────────
# append=True  → 追加到已有 D_docs.jsonl / D_chunks.jsonl
# append=False → 覆盖（首次运行或重建时使用）
docs, chunks = chunk_all(append=False)

# ── 基础统计 ─────────────────────────────────────────────────
print(f"\n{'='*50}")
print(f"写入文档数  : {len(docs)}")
print(f"写入 chunk 数: {len(chunks)}")

# 按分类统计
cat_counts = Counter(c["category"] for c in chunks)
for cat, cnt in sorted(cat_counts.items()):
    print(f"  {cat:<20} {cnt:>4} chunks")

# ── 抽查 chunk 文本 ──────────────────────────────────────────
print(f"\n── 随机抽查 3 条 chunk ──")
import random
for c in random.sample(chunks, min(3, len(chunks))):
    print(f"\nchunk_id     : {c['chunk_id']}")
    print(f"site / cat   : {c['site_key']} / {c['category']}")
    print(f"section_path : {c['section_path']}")
    print(f"words        : {c['word_count']}  overlap={c['has_overlap']}")
    print("text ↓")
    print(c["text"][:400])
    print("...")

# ── JSONL 文件校验 ───────────────────────────────────────────
print(f"\n── JSONL 校验 ──")
for fpath in [OUT_DOCS, OUT_CHUNKS]:
    records = [json.loads(l) for l in fpath.read_text().splitlines() if l.strip()]
    print(f"  {fpath.name:<25} {len(records):>5} 条  ✓")
# Out:
# ============================================================
# Collection D — Chunking
# Files: 269
# ============================================================
#   ok  bananasplitfest/bananasplitfest.com.md                    7 chunks
#   ok  bananasplitfest/bananasplitfest.com__activities.md        6 chunks
#   skip  bananasplitfest/bananasplitfest.com__activities__crafts-games-activities.md  (no content)
#   skip  bananasplitfest/bananasplitfest.com__activities__entertainment.md  (no content)
#   ok  bananasplitfest/bananasplitfest.com__activities__food.md   1 chunks
#   skip  bananasplitfest/bananasplitfest.com__activities__over-21-area.md  (no content)
#   skip  bananasplitfest/bananasplitfest.com__activities__participating-vendors.md  (no content)
#   ok  bananasplitfest/bananasplitfest.com__events.md            6 chunks
#   ok  bananasplitfest/bananasplitfest.com__events__5k-banana-run.md   1 chunks
#   ok  bananasplitfest/bananasplitfest.com__events__banana-challenge.md   1 chunks
#   ok  bananasplitfest/bananasplitfest.com__events__blood-drive.md   1 chunks
#   ok  bananasplitfest/bananasplitfest.com__events__cornhole-tournament.md   1 chunks
#   ok  bananasplitfest/bananasplitfest.com__events__great-american-banana-baking-contest.md   4 chunks
#   ok  bananasplitfest/bananasplitfest.com__events__princess-pageant.md   6 chunks
#   ok  bananasplitfest/bananasplitfest.com__events__yellow-tie-gala.md   1 chunks
#   ok  carnegiemuseums/carnegiemuseums.org__about-us.md          5 chunks
#   ok  carnegiemuseums/carnegiemuseums.org__about-us__contact-us.md   2 chunks
#   ok  carnegiemuseums/carnegiemuseums.org__about-us__our-impact.md   3 chunks
#   ok  carnegiemuseums/carnegiemuseums.org__about-us__our-leaders.md   5 chunks
#   ok  carnegiemuseums/carnegiemuseums.org__about-us__our-leaders__trustees-boards.md   7 chunks
#   ok  carnegiemuseums/carnegiemuseums.org__accessibility.md     2 chunks
#   ok  littleitalydays/littleitalydays.com.md                    7 chunks
#   ok  littleitalydays/littleitalydays.com__about-us.md          1 chunks
#   ok  littleitalydays/littleitalydays.com__bloomfield-businesses.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__community-report.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__entertainment-schedule.md   5 chunks
#   ok  littleitalydays/littleitalydays.com__faq.md               1 chunks
#   ok  littleitalydays/littleitalydays.com__getting-around.md    6 chunks
#   ok  littleitalydays/littleitalydays.com__vendor.md            2 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2019__07__2019-LID-vendor-map.pdf.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2019__07__GolffatherEntryForm.pdf.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2019__07__GolffatherEventOverview.pdf.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2019__10__2019-Report-to-Community-2.p.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2021__08__porta-john-map.pdf.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2024__01__2024-Bloomfield-LID-Contract.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2025-LID-Setup.pdf.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2025__07__Miss-Little-Italy-2025.pdf.md   1 chunks
#   ok  littleitalydays/littleitalydays.com__wp-content__uploads__2026-Bloomfield-LID-Contract-Bloomfiel.md   1 chunks
#   ok  penguins/nhl.com__penguins.md                             6 chunks
#   ok  penguins/nhl.com__penguins__community.md                  2 chunks
#   ok  penguins/nhl.com__penguins__community__appearances.md     3 chunks
#   ok  penguins/nhl.com__penguins__community__leadership-program.md   3 chunks
#   ok  penguins/nhl.com__penguins__community__penguins-future-goals.md   5 chunks
#   ok  penguins/nhl.com__penguins__community__youth-hockey-landing.md   3 chunks
#   ok  penguins/nhl.com__penguins__fans.md                       2 chunks
#   ok  penguins/nhl.com__penguins__fans__schedule-downloads.md   3 chunks
#   ok  penguins/nhl.com__penguins__fans__texts.md                3 chunks
#   ok  penguins/nhl.com__penguins__multimedia__email.md          3 chunks
#   ok  penguins/nhl.com__penguins__prospects.md                  3 chunks
#   ok  penguins/nhl.com__penguins__roster.md                     3 chunks
#   ok  penguins/nhl.com__penguins__schedule.md                   3 chunks
#   ok  penguins/nhl.com__penguins__team__hall-of-fame.md         3 chunks
#   ok  penguins/nhl.com__penguins__team__staff.md                3 chunks
#   ok  penguins/nhl.com__penguins__tickets.md                    3 chunks
#   ok  penguins/nhl.com__penguins__tickets__groups.md            3 chunks
#   ok  penguins/nhl.com__penguins__tickets__mini-plans.md        4 chunks
#   ok  penguins/nhl.com__penguins__tickets__pps-all-stars.md     8 chunks
#   ok  penguins/nhl.com__penguins__tickets__premium-landing.md   8 chunks
#   ok  penguins/nhl.com__penguins__tickets__promotional-schedule.md   7 chunks
#   ok  penguins/nhl.com__penguins__tickets__season-tickets.md    4 chunks
#   ok  penguins/nhl.com__penguins__tickets__single-game-tickets.md   3 chunks
#   ok  penguins/nhl.com__penguins__tickets__special-offers-landing.md   3 chunks
#   ok  penguins/nhl.com__penguins__tickets__ticket-information-request.md   2 chunks
#   ok  pghtacofest/pghtacofest.com__about.md                     2 chunks
#   ok  picklesburgh/picklesburgh.com.md                          2 chunks
#   ok  picklesburgh/picklesburgh.com__contact.md                 4 chunks
#   ok  picklesburgh/picklesburgh.com__photo-gallery.md           1 chunks
#   skip  picklesburgh/picklesburgh.com__sponsors.md  (no content)
#   skip  picklesburgh/picklesburgh.com__vendors.md  (no content)
#   ok  picklesburgh/picklesburgh.com__visit.md                   4 chunks
#   ok  picklesburgh/picklesburgh.com__wp-content__uploads__2026__02__Picklesburgh-2026-Price-Fact-Sh.md   1 chunks
#   ok  pirates/mlb.com__pirates.md                               6 chunks
#   ok  pirates/mlb.com__pirates__apps__ballpark.md               5 chunks
#   ok  pirates/mlb.com__pirates__ballpark.md                     2 chunks
#   ok  pirates/mlb.com__pirates__ballpark__information.md        2 chunks
#   ok  pirates/mlb.com__pirates__ballpark__seating-map__3d.md    2 chunks
#   ok  pirates/mlb.com__pirates__ballpark__tours.md              6 chunks
#   ok  pirates/mlb.com__pirates__roster.md                       3 chunks
#   ok  pirates/mlb.com__pirates__roster__40-man.md               3 chunks
#   ok  pirates/mlb.com__pirates__roster__coaches.md              3 chunks
#   ok  pirates/mlb.com__pirates__roster__depth-chart.md          3 chunks
#   ok  pirates/mlb.com__pirates__roster__transactions.md         3 chunks
#   ok  pirates/mlb.com__pirates__team__broadcasters.md           9 chunks
#   ok  pirates/mlb.com__pirates__team__front-office.md           5 chunks
#   ok  pirates/mlb.com__pirates__tickets.md                      2 chunks
#   ok  pirates/mlb.com__pirates__tickets__events.md              2 chunks
#   ok  pirates/mlb.com__pirates__tickets__group-tickets.md       3 chunks
#   ok  pirates/mlb.com__pirates__tickets__group-tickets__hospitality-and-suites.md  10 chunks
#   ok  pirates/mlb.com__pirates__tickets__mini-plans.md          2 chunks
#   ok  pirates/mlb.com__pirates__tickets__mobile__faqs.md       10 chunks
#   ok  pirates/mlb.com__pirates__tickets__premium.md             2 chunks
#   ok  pirates/mlb.com__pirates__tickets__premium__pittsburgh-baseball-club.md   2 chunks
#   ok  pirates/mlb.com__pirates__tickets__promotions__2026.md    7 chunks
#   ok  pirates/mlb.com__pirates__tickets__season-tickets.md      2 chunks
#   ok  pirates/mlb.com__pirates__tickets__single-game-tickets.md   2 chunks
#   ok  pirates/mlb.com__pirates__tickets__spring-training.md     4 chunks
#   ok  pittsburgh_restaurants.md                               187 chunks
#   ok  pittsburghopera/pittsburghopera.org.md                    3 chunks
#   ok  pittsburghopera/pittsburghopera.org__about.md             3 chunks
#   ok  pittsburghopera/pittsburghopera.org__about__financial-documents.md   2 chunks
#   ok  pittsburghopera/pittsburghopera.org__about__mission-history.md   4 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__subscriptions__choose-your-own.md   2 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__subscriptions__pnc-pops-concerts.md   3 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__tickets__group-sales.md   3 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__tickets__pso-go.md   3 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__tickets__seating-charts.md   2 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__visit-landing.md   4 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__visit-landing__directions-parking-lodging.md   5 chunks
#   ok  pittsburghsymphony/pittsburghsymphony.org__pso_home__web__visit-landing__frequently-asked-questions.md   4 chunks
#   ok  steelers/steelers.com.md                                  9 chunks
#   ok  steelers/steelers.com__audio__steelers-audio-network.md   1 chunks
#   ok  steelers/steelers.com__community.md                       4 chunks
#   ok  steelers/steelers.com__deutschland.md                     2 chunks
#   ok  steelers/steelers.com__draft.md                          10 chunks
#   ok  steelers/steelers.com__draft26.md                         1 chunks
#   ok  steelers/steelers.com__draft__2026-mock-draft-01.md       1 chunks
#   ok  steelers/steelers.com__espanol.md                         5 chunks
#   ok  steelers/steelers.com__fans.md                            4 chunks
#   ok  steelers/steelers.com__fans__official-steelers-mobile-app.md   1 chunks
#   ok  steelers/steelers.com__history.md                         3 chunks
#   ok  steelers/steelers.com__history__terrible-towel.md         1 chunks
#   ok  steelers/steelers.com__ireland.md                         3 chunks
#   ok  steelers/steelers.com__legends.md                         5 chunks
#   ok  steelers/steelers.com__museum.md                          6 chunks
#   ok  steelers/steelers.com__photos.md                          3 chunks
#   ok  steelers/steelers.com__photos__photos-karl-s-top-pics-of-2025-top-10.md   3 chunks
#   ok  steelers/steelers.com__schedule.md                        7 chunks
#   ok  steelers/steelers.com__schedule__event-calendar.md        2 chunks
#   ok  steelers/steelers.com__schedule__printable.md             1 chunks
#   ok  steelers/steelers.com__team__players-roster.md            2 chunks
#   ok  steelers/steelers.com__tickets.md                         2 chunks
#   ok  steelers/steelers.com__tickets__digital-tickets.md        7 chunks
#   ok  steelers/steelers.com__women.md                           5 chunks
#   ok  steelers/steelers.com__youth.md                           2 chunks
#   ok  trustarts/trustarts.org.md                                8 chunks
#   ok  trustarts/trustarts.org__calendar.md                     14 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Ballet__26_Dance.md  10 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Broadway__26_Musical_Theater.md  17 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Comedy.md        11 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Concert.md       14 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Drama.md          9 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Family.md        13 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Free.md          17 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Live_Music.md    15 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Magic.md         13 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Talks__26_Poetry.md  14 chunks
#   ok  trustarts/trustarts.org__calendar_genre_Virtual.md        6 chunks
#   ok  trustarts/trustarts.org__calendar_organization_id_1.md   17 chunks
#   ok  trustarts/trustarts.org__event__30974-2026__2026-2027-trust-season-announcement.md   3 chunks
#   ok  trustarts/trustarts.org__pct_home__about.md               4 chunks
#   ok  trustarts/trustarts.org__pct_home__education.md           2 chunks
#   ok  trustarts/trustarts.org__pct_home__engagement.md          2 chunks
#   ok  trustarts/trustarts.org__pct_home__events.md              1 chunks
#   ok  trustarts/trustarts.org__pct_home__events__series.md      2 chunks
#   ok  trustarts/trustarts.org__pct_home__rent.md                4 chunks
#   ok  trustarts/trustarts.org__pct_home__support.md             2 chunks
#   ok  trustarts/trustarts.org__pct_home__visit.md               1 chunks
#   ok  trustarts/trustarts.org__pct_home__visual-arts.md        10 chunks
#   ok  trustarts/trustarts.org__production__100797__list_performances.md   2 chunks
#   ok  trustarts/trustarts.org__production__102089__ondrej-psenicka-in-52-lovers.md   4 chunks
#   ok  trustarts/trustarts.org__production__102497__patti-lupone-matters-of-the-heart.md   4 chunks
#   ok  trustarts/trustarts.org__production__102505__international-guitar-night.md   4 chunks
#   ok  trustarts/trustarts.org__production__102946__an-evening-with-joe-bonamassa.md   3 chunks
#   ok  trustarts/trustarts.org__production__104042__jason-isbell-and-the-400-unit.md   4 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_10.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_11.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_12.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_13.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_14.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_2.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_3.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_4.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_5.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_6.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals___page_7.md   2 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events.md  39 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__3-rivers-comicon.md   6 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__americas-mile.md   5 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__bloomfield-little-italy-da.md  11 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__juneteenth.md  12 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__kennywood-holiday-lights.md   8 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__millvale-music-festival.md   7 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__pittsburgh-home-garden-sho.md  12 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__pittsburgh-international-a.md  10 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__pittsburgh-winter-beerfest.md   7 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__pogopalooza.md   8 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__rock-reggae-relief.md   6 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__rush-to-crush-cancer.md  16 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__spirits-of-the-burgh.md   6 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__annual-events__tekko.md  11 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__film-festivals.md  17 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__film-festivals__jfilm-festival.md  16 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__film-festivals__pittsburgh-independent-fi.md   9 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__food-festivals.md  17 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__food-festivals__soul-food-festival.md   6 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__food-festivals__the-original-pittsburgh-t.md   7 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__halloween-events.md  22 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__holidays.md  23 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__marathons-runs-walks.md  16 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__marathons-runs-walks__hell-hath-no-hurry.md   7 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__oktoberfest-pittsburgh.md   6 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__submit-your-event.md   1 chunks
#   ok  visitpittsburgh/visitpittsburgh.com__events-festivals__this-week-in-pittsburgh.md   9 chunks
#
# ============================================================
# Per-site summary
# ============================================================
#   bananasplitfest                 11 files    35 chunks  ~  2910 words
#   carnegiemuseums                  6 files    24 chunks  ~  1929 words
#   littleitalydays                 17 files    33 chunks  ~  3138 words
#   penguins                        25 files    93 chunks  ~ 20971 words
#   pghtacofest                      1 files     2 chunks  ~    60 words
#   picklesburgh                     5 files    12 chunks  ~   630 words
#   pirates                         25 files   100 chunks  ~ 31552 words
#   D                                1 files   187 chunks  ~ 18750 words
#   pittsburghopera                 30 files   134 chunks  ~ 24245 words
#   pittsburghrestaurantweek        18 files    28 chunks  ~  3606 words
#   pittsburghsymphony              28 files   122 chunks  ~ 10906 words
#   steelers                        25 files    90 chunks  ~ 40099 words
#   trustarts                       30 files   230 chunks  ~ 14800 words
#   visitpittsburgh                 40 files   344 chunks  ~ 42623 words
#
#   Total                          262 files  1434 chunks  ~216219 words
#
#   Wrote:
#     D_docs.jsonl   : 262 records  (97.5 KB)
#     D_chunks.jsonl : 1434 records  (11126.4 KB)
#
# ==================================================
# 写入文档数  : 262
# 写入 chunk 数: 1434
#                         187 chunks
#   food                  454 chunks
#   music_culture         510 chunks
#   sports                283 chunks
#
# ── 随机抽查 3 条 chunk ──
#
# chunk_id     : D_pirates_0011__0005
# site / cat   : pirates / sports
# section_path : MOBILE TICKETING FAQ > MLB BALLPARK APP - TICKET FORWARDING
# words        : 1083  overlap=True
# text ↓
# [Site: mlb.demdex.net is blocked | Category: sports]
# Section: MOBILE TICKETING FAQ > MLB BALLPARK APP - TICKET FORWARDING
#
# What is Ticket Forwarding?
#
# The MLB Ballpark app allows you to easily forward tickets to family, friends, colleagues, account partners and others with whom you wish to share your tickets so that they can use their ticket on their personal phone.
#
# How do I forward a ticket?
#
# Fr
# ...
#
# chunk_id     : D_D_pittsburgh_restaurants__0186
# site / cat   : D /
# section_path : Pittsburgh Restaurants Directory > Medi's on Market
# words        : 109  overlap=False
# text ↓
# [Site: Pittsburgh Restaurants Directory | Category: ]
# Section: Pittsburgh Restaurants Directory > Medi's on Market
#
# Address: 431 Market St., Pittsburgh, Pennsylvania 15222
# Phone: (412) 261-4976
# Detail Page: [https://www.visitpittsburgh.com/directory/medis-on-market/](https://www.visitpittsburgh.com/directory/medis-on-market/)
#
# Summary: Greek restaurant with "Build Your Own" concept where custo
# ...
#
# chunk_id     : D_pittsburghsymphony_0028__0003
# site / cat   : pittsburghsymphony / music_culture
# section_path : Upcoming Fundraising Events > **Maestro’s Wine Dinner**
# words        : 97  overlap=True
# text ↓
# [Site: **Manfred Honeck** | Category: music_culture]
# Section: Upcoming Fundraising Events > **Maestro’s Wine Dinner**
#
# The PSO’s annual Maestro’s Wine Dinner was created several years ago as an evening of great wine, food, music, and friendship. Held each year at the Duquesne Club, the event co-chairs craft an evening featuring exclusive wine paired with an incredible meal. This event features a p
# ...
#
# ── JSONL 校验 ──
#   D_docs.jsonl                262 条  ✓
#   D_chunks.jsonl             1434 条  ✓

# %%
import sys, json
from pathlib import Path
from collections import Counter

sys.path.insert(0, "scripts/")  # adjust if script is elsewhere
from scripts.chunk_collection_a_wiki import run, OUT_DOCS, OUT_CHUNKS

# ── Run ──────────────────────────────────────────────────────────────────────
# append=False  -> overwrite (default; first run or full rebuild)
# append=True   -> append to existing JSONL
# dry_run=True  -> print stats only, no file writes
docs, chunks = run(append=False)

# ── Quick stats ──────────────────────────────────────────────────────────────
print(f"\n{'='*50}")
print(f"Docs    : {len(docs)}")
print(f"Chunks  : {len(chunks)}")
avg_wc = sum(c['word_count'] for c in chunks) / len(chunks) if chunks else 0
print(f"Avg chunk size : {avg_wc:.0f} words")

# Chunk size distribution
buckets = Counter(
    "<100"  if c['word_count'] <  100 else
    "100-200" if c['word_count'] < 200 else
    "200-300" if c['word_count'] < 300 else
    "300-450" if c['word_count'] < 450 else "450+"
    for c in chunks
)
print("\nChunk size distribution:")
for label in ["<100", "100-200", "200-300", "300-450", "450+"]:
    print(f"  {label:<10} {buckets[label]:>5} chunks")

# ── Sample chunk ─────────────────────────────────────────────────────────────
print("\n── Sample chunk ──")
import random
sample = random.choice(chunks)
print(f"chunk_id   : {sample['chunk_id']}")
print(f"md_title   : {sample['md_title']}")
print(f"section    : {sample['section']}")
print(f"subsection : {sample['subsection']}")
print(f"words      : {sample['word_count']}")
print("\ntext:")
print(sample['text'][:500])

# ── JSONL validation ─────────────────────────────────────────────────────────
print("\n── JSONL validation ──")
for fpath in [OUT_DOCS, OUT_CHUNKS]:
    records = [json.loads(l) for l in fpath.read_text().splitlines() if l.strip()]
    print(f"  {fpath.name:<25} {len(records):>6} records  ✓")
# Out:
# ============================================================
# Collection A — Wikipedia Chunking
# Files: 51
# ============================================================
#   ok    Andrew Carnegie - Wikipedia.md                        56 chunks  ~11069 words
#   ok    Andrew Mellon - Wikipedia.md                          35 chunks  ~ 6903 words
#   ok    Association of American Universities - Wikipedia.md    20 chunks  ~ 3163 words
#   ok    Association of Independent Technological Universities - Wikipedia.md     4 chunks  ~  283 words
#   ok    Astrobotic Technology - Wikipedia.md                  10 chunks  ~ 1719 words
#   ok    Carnegie Library of Pittsburgh - Wikipedia.md          6 chunks  ~  688 words
#   ok    Carnegie Mellon College of Engineering - Wikipedia.md     4 chunks  ~  535 words
#   ok    Carnegie Mellon College of Fine Arts - Wikipedia.md     2 chunks  ~  525 words
#   ok    Carnegie Mellon School of Art - Wikipedia.md           6 chunks  ~  812 words
#   ok    Carnegie Mellon School of Computer Science - Wikipedia.md    15 chunks  ~ 2034 words
#   ok    Carnegie Mellon School of Design - Wikipedia.md       10 chunks  ~ 1214 words
#   ok    Carnegie Mellon School of Drama - Wikipedia.md         7 chunks  ~ 1334 words
#   ok    Carnegie Mellon School of Music - Wikipedia.md         1 chunks  ~  275 words
#   ok    Carnegie Mellon Tartans football - Wikipedia.md       19 chunks  ~ 3018 words
#   ok    Carnegie Mellon University - Wikipedia.md             49 chunks  ~ 9280 words
#   ok    Carnegie Mellon University Africa - Wikipedia.md       3 chunks  ~  132 words
#   ok    Carnegie Mellon University Computational Biology Department - Wikipedia.md     4 chunks  ~  510 words
#   ok    Carnegie Mellon University in Qatar - Wikipedia.md     6 chunks  ~  318 words
#   ok    Carnegie Mellon University traditions - Wikipedia.md    16 chunks  ~ 2812 words
#   ok    Carnegie School - Wikipedia.md                         9 chunks  ~ 1858 words
#   ok    Dietrich College of Humanities and Social Sciences - Wikipedia.md     8 chunks  ~  872 words
#   ok    Disney Research - Wikipedia.md                         2 chunks  ~  119 words
#   ok    Entertainment Technology Center - Wikipedia.md         9 chunks  ~  414 words
#   ok    EteRNA - Wikipedia.md                                  5 chunks  ~ 1082 words
#   ok    Forbes Expedition - Wikipedia.md                       6 chunks  ~  680 words
#   ok    Fort Duquesne - Wikipedia.md                           7 chunks  ~ 1294 words
#   ok    Heinz College - Wikipedia.md                          13 chunks  ~ 2578 words
#   ok    Herbert A. Simon - Wikipedia.md                       23 chunks  ~ 4414 words
#   ok    Human–Computer Interaction Institute - Wikipedia.md     6 chunks  ~  777 words
#   ok    Hunt Institute for Botanical Documentation - Wikipedia.md     4 chunks  ~  300 words
#   ok    IBM_Google Cloud Computing University Initiative - Wikipedia.md     3 chunks  ~  459 words
#   ok    Information Networking Institute - Wikipedia.md        5 chunks  ~  471 words
#   ok    Language Technologies Institute - Wikipedia.md         5 chunks  ~  432 words
#   ok    List of Carnegie Mellon University fraternities and sororities - Wikipedia.md     7 chunks  ~  225 words
#   ok    List of Carnegie Mellon University people - Wikipedia.md    58 chunks  ~ 8981 words
#   ok    Main Building, U.S. Bureau of Mines - Wikipedia.md     2 chunks  ~  132 words
#   ok    Margaret Morrison Carnegie College - Wikipedia.md      5 chunks  ~  479 words
#   ok    Meadowcroft Rockshelter - Wikipedia.md                 9 chunks  ~ 1185 words
#   ok    Mellon College of Science - Wikipedia.md               5 chunks  ~  525 words
#   ok    Mellon Institute of Industrial Research - Wikipedia.md     5 chunks  ~  800 words
#   ok    Million Book Project - Wikipedia.md                    6 chunks  ~  558 words
#   ok    Newell Simon Hall - Wikipedia.md                       1 chunks  ~   51 words
#   ok    Pennsylvania Governor's School for the Sciences - Wikipedia.md    11 chunks  ~ 1689 words
#   ok    Pittsburgh Supercomputing Center - Wikipedia.md        6 chunks  ~  701 words
#   ok    Robotics Institute - Wikipedia.md                      5 chunks  ~  510 words
#   ok    Scotch'n'Soda Theatre - Wikipedia.md                  13 chunks  ~ 2007 words
#   ok    Shannopin's Town - Wikipedia.md                       16 chunks  ~ 2512 words
#   ok    Software Engineering Institute - Wikipedia.md         16 chunks  ~ 1017 words
#   ok    Tepper School of Business - Wikipedia.md              17 chunks  ~ 2845 words
#   ok    Walking to the Sky - Wikipedia.md                      2 chunks  ~  350 words
#   ok    Whiskey Rebellion - Wikipedia.md                      30 chunks  ~ 6186 words
#
# ============================================================
#   Files   : 51
#   Chunks  : 592
#   Words   : 93,127
#   Avg chunk size : 159 words
#   -> A_docs.jsonl   : 13.8 KB
#   -> A_chunks.jsonl : 802.9 KB
#
# ==================================================
# Docs    : 51
# Chunks  : 592
# Avg chunk size : 159 words
#
# Chunk size distribution:
#   <100         186 chunks
#   100-200      175 chunks
#   200-300      211 chunks
#   300-450       20 chunks
#   450+           0 chunks
#
# ── Sample chunk ──
# chunk_id   : A_wiki_Carnegie Mellon University - Wikipedia__0028
# md_title   :
# section    : Discoveries and innovation
# subsection : Natural sciences
# words      : 211
#
# text:
#  — Discoveries and innovation — Natural sciences
#
# - Electron diffraction – Clinton Davisson won the 1937 Nobel Prize in Physics for his discovery of electron diffraction in the famous Davisson–Germer experiment, which confirmed the de Broglie hypothesis that particles of matter have a wave-like nature, which is a central tenet of quantum mechanics. In particular, their observation of diffraction allowed the first measurement of a wavelength for electrons.
# - Kevlar – Developed by Stephanie Kwolek
#
# ── JSONL validation ──
#   A_docs.jsonl                  51 records  ✓
#   A_chunks.jsonl               592 records  ✓
